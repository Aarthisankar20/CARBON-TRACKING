# %% [markdown]
# <a href="https://colab.research.google.com/github/Aarthisankar20/CARBON-TRACKING/blob/main/cv_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow

# %%
img = cv2.imread("/content/WhatsApp Image 2024-12-05 at 8.27.08 PM.jpeg")

if img is None:
    print("Error: Image not found or unable to load.")
else:
    edges = cv2.Canny(img, 100, 100)
    cv2_imshow(edges)

    save_path = "/content/Web_Photo_Editor_Edges.jpg"
    cv2.imwrite(save_path, edges)
    print(f"Image saved at {save_path}")
# Out:
# <PIL.Image.Image image mode=L size=1200x1600>
# Image saved at /content/Web_Photo_Editor_Edges.jpg
